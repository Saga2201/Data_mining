# %%
import pandas as pd

# %%
df = pd.read_csv("raw_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50418 entries, 0 to 50417
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    0 non-null      float64
#  1   iso_code                 50418 non-null  object
#  2   location                 50418 non-null  object
#  3   date                     50418 non-null  object
#  4   total_cases              47324 non-null  float64
#  5   total_deaths             39228 non-null  float64
#  6   stringency_index         43292 non-null  float64
#  7   population               50418 non-null  int64
#  8   gdp_per_capita           44706 non-null  float64
#  9   human_development_index  44216 non-null  float64
#  10  Unnamed: 10              50418 non-null  object
#  11  Unnamed: 11              50418 non-null  object
#  12  Unnamed: 12              50418 non-null  object
#  13  Unnamed: 13              50418 non-null  float64
# ...

# %% [markdown]
# ## A. Show dimensions

# %%
dimention = pd.DataFrame(df)
dimention
# Out:
#        index iso_code     location        date  total_cases  total_deaths  \
# 0        NaN      AFG  Afghanistan  2019-12-31          0.0           0.0
# 1        NaN      AFG  Afghanistan  2020-01-01          0.0           0.0
# 2        NaN      AFG  Afghanistan  2020-01-02          0.0           0.0
# 3        NaN      AFG  Afghanistan  2020-01-03          0.0           0.0
# 4        NaN      AFG  Afghanistan  2020-01-04          0.0           0.0
# ...      ...      ...          ...         ...          ...           ...
# 50413    NaN      ZWE     Zimbabwe  2020-10-15       8055.0         231.0
# 50414    NaN      ZWE     Zimbabwe  2020-10-16       8075.0         231.0
# 50415    NaN      ZWE     Zimbabwe  2020-10-17       8099.0         231.0
# 50416    NaN      ZWE     Zimbabwe  2020-10-18       8110.0         231.0
# 50417    NaN      ZWE     Zimbabwe  2020-10-19       8147.0         231.0
#
#        stringency_index  population  gdp_per_capita  human_development_index  \
# ...

# %% [markdown]
# ## B. Show metadata

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50418 entries, 0 to 50417
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    0 non-null      float64
#  1   iso_code                 50418 non-null  object
#  2   location                 50418 non-null  object
#  3   date                     50418 non-null  object
#  4   total_cases              47324 non-null  float64
#  5   total_deaths             39228 non-null  float64
#  6   stringency_index         43292 non-null  float64
#  7   population               50418 non-null  int64
#  8   gdp_per_capita           44706 non-null  float64
#  9   human_development_index  44216 non-null  float64
#  10  Unnamed: 10              50418 non-null  object
#  11  Unnamed: 11              50418 non-null  object
#  12  Unnamed: 12              50418 non-null  object
#  13  Unnamed: 13              50418 non-null  float64
# ...

# %% [markdown]
# ## C. Handle missing values
# * by dropping concerned rows
# * by setting appropriate values at null/none/blank cells

# %%
df[df.isnull().any(axis=1)]
# Out:
#        index iso_code     location        date  total_cases  total_deaths  \
# 0        NaN      AFG  Afghanistan  2019-12-31          0.0           0.0
# 1        NaN      AFG  Afghanistan  2020-01-01          0.0           0.0
# 2        NaN      AFG  Afghanistan  2020-01-02          0.0           0.0
# 3        NaN      AFG  Afghanistan  2020-01-03          0.0           0.0
# 4        NaN      AFG  Afghanistan  2020-01-04          0.0           0.0
# ...      ...      ...          ...         ...          ...           ...
# 50413    NaN      ZWE     Zimbabwe  2020-10-15       8055.0         231.0
# 50414    NaN      ZWE     Zimbabwe  2020-10-16       8075.0         231.0
# 50415    NaN      ZWE     Zimbabwe  2020-10-17       8099.0         231.0
# 50416    NaN      ZWE     Zimbabwe  2020-10-18       8110.0         231.0
# 50417    NaN      ZWE     Zimbabwe  2020-10-19       8147.0         231.0
#
#        stringency_index  population  gdp_per_capita  human_development_index  \
# ...

# %% [markdown]
# * by dropping concerned rows

# %%
df2 = df.dropna()
df2
# Out:
# Empty DataFrame
# Columns: [index, iso_code, location, date, total_cases, total_deaths, stringency_index, population, gdp_per_capita, human_development_index, Unnamed: 10, Unnamed: 11, Unnamed: 12, Unnamed: 13, Unnamed: 14]
# Index: []

# %% [markdown]
# * by setting appropriate values at null/none/blank cells

# %%
df.isnull().sum()
# Out:
# index                      50418
# iso_code                       0
# location                       0
# date                           0
# total_cases                 3094
# total_deaths               11190
# stringency_index            7126
# population                     0
# gdp_per_capita              5712
# human_development_index     6202
# Unnamed: 10                    0
# Unnamed: 11                    0
# Unnamed: 12                    0
# Unnamed: 13                    0
# Unnamed: 14                    0
# dtype: int64

# %%
df['total_cases'] = df['total_cases'].fillna(value='none')

# %%
df.isnull().sum()
# Out:
# index                      50418
# iso_code                       0
# location                       0
# date                           0
# total_cases                    0
# total_deaths               11190
# stringency_index            7126
# population                     0
# gdp_per_capita              5712
# human_development_index     6202
# Unnamed: 10                    0
# Unnamed: 11                    0
# Unnamed: 12                    0
# Unnamed: 13                    0
# Unnamed: 14                    0
# dtype: int64

# %% [markdown]
# ## D. Handle dates (as day, month, year)

# %%
#pd.read_csv('raw_data.csv', parse_dates=['date'], dayfirst=False)
pd.read_csv('raw_data.csv', parse_dates=['date'], dayfirst=True)
# Out:
#        index iso_code     location       date  total_cases  total_deaths  \
# 0        NaN      AFG  Afghanistan 2019-12-31          0.0           0.0
# 1        NaN      AFG  Afghanistan 2020-01-01          0.0           0.0
# 2        NaN      AFG  Afghanistan 2020-01-02          0.0           0.0
# 3        NaN      AFG  Afghanistan 2020-01-03          0.0           0.0
# 4        NaN      AFG  Afghanistan 2020-01-04          0.0           0.0
# ...      ...      ...          ...        ...          ...           ...
# 50413    NaN      ZWE     Zimbabwe 2020-10-15       8055.0         231.0
# 50414    NaN      ZWE     Zimbabwe 2020-10-16       8075.0         231.0
# 50415    NaN      ZWE     Zimbabwe 2020-10-17       8099.0         231.0
# 50416    NaN      ZWE     Zimbabwe 2020-10-18       8110.0         231.0
# 50417    NaN      ZWE     Zimbabwe 2020-10-19       8147.0         231.0
#
#        stringency_index  population  gdp_per_capita  human_development_index  \
# ...

# %%
import datetime
df = pd.read_csv("raw_data.csv")
df['date'] = df['date'].astype('datetime64')
df['date'] = df['date'].dt.strftime('%d/%m/%Y')
df.head(5)
# Out:
#    index iso_code     location        date  total_cases  total_deaths  \
# 0    NaN      AFG  Afghanistan  31/12/2019          0.0           0.0
# 1    NaN      AFG  Afghanistan  01/01/2020          0.0           0.0
# 2    NaN      AFG  Afghanistan  02/01/2020          0.0           0.0
# 3    NaN      AFG  Afghanistan  03/01/2020          0.0           0.0
# 4    NaN      AFG  Afghanistan  04/01/2020          0.0           0.0
#
#    stringency_index  population  gdp_per_capita  human_development_index  \
# 0               0.0    38928341        1803.987                    0.498
# 1               0.0    38928341        1803.987                    0.498
# 2               0.0    38928341        1803.987                    0.498
# 3               0.0    38928341        1803.987                    0.498
# 4               0.0    38928341        1803.987                    0.498
#
#   Unnamed: 10 Unnamed: 11 Unnamed: 12  Unnamed: 13  Unnamed: 14
# ...

# %%
import datetime
df = pd.read_csv("raw_data.csv")
df['date'] = df['date'].astype('datetime64')
df['dateOnly'] = df['date'].dt.strftime('%d')
df['month'] = df['date'].dt.strftime('%m')
df['year'] = df['date'].dt.strftime('%Y')
print(df['dateOnly'])
# Out:
# 0        31
# 1        01
# 2        02
# 3        03
# 4        04
#          ..
# 50413    15
# 50414    16
# 50415    17
# 50416    18
# 50417    19
# Name: dateOnly, Length: 50418, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50418 entries, 0 to 50417
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    0 non-null      float64
#  1   iso_code                 50418 non-null  object
#  2   location                 50418 non-null  object
#  3   date                     50418 non-null  datetime64[ns]
#  4   total_cases              47324 non-null  float64
#  5   total_deaths             39228 non-null  float64
#  6   stringency_index         43292 non-null  float64
#  7   population               50418 non-null  int64
#  8   gdp_per_capita           44706 non-null  float64
#  9   human_development_index  44216 non-null  float64
#  10  Unnamed: 10              50418 non-null  object
#  11  Unnamed: 11              50418 non-null  object
#  12  Unnamed: 12              50418 non-null  object
# ...

# %%
df.head()
# Out:
#    index iso_code     location       date  total_cases  total_deaths  \
# 0    NaN      AFG  Afghanistan 2019-12-31          0.0           0.0
# 1    NaN      AFG  Afghanistan 2020-01-01          0.0           0.0
# 2    NaN      AFG  Afghanistan 2020-01-02          0.0           0.0
# 3    NaN      AFG  Afghanistan 2020-01-03          0.0           0.0
# 4    NaN      AFG  Afghanistan 2020-01-04          0.0           0.0
#
#    stringency_index  population  gdp_per_capita  human_development_index  \
# 0               0.0    38928341        1803.987                    0.498
# 1               0.0    38928341        1803.987                    0.498
# 2               0.0    38928341        1803.987                    0.498
# 3               0.0    38928341        1803.987                    0.498
# 4               0.0    38928341        1803.987                    0.498
#
#   Unnamed: 10 Unnamed: 11 Unnamed: 12  Unnamed: 13  Unnamed: 14 dateOnly  \
# ...

# %%
import datetime
df = pd.read_csv("raw_data.csv")
print(df['date'])
# Out:
# 0        2019-12-31
# 1        2020-01-01
# 2        2020-01-02
# 3        2020-01-03
# 4        2020-01-04
#             ...
# 50413    2020-10-15
# 50414    2020-10-16
# 50415    2020-10-17
# 50416    2020-10-18
# 50417    2020-10-19
# Name: date, Length: 50418, dtype: object

# %% [markdown]
# ## E. Handle duplicate rows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50418 entries, 0 to 50417
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    0 non-null      float64
#  1   iso_code                 50418 non-null  object
#  2   location                 50418 non-null  object
#  3   date                     50418 non-null  object
#  4   total_cases              47324 non-null  float64
#  5   total_deaths             39228 non-null  float64
#  6   stringency_index         43292 non-null  float64
#  7   population               50418 non-null  int64
#  8   gdp_per_capita           44706 non-null  float64
#  9   human_development_index  44216 non-null  float64
#  10  Unnamed: 10              50418 non-null  object
#  11  Unnamed: 11              50418 non-null  object
#  12  Unnamed: 12              50418 non-null  object
#  13  Unnamed: 13              50418 non-null  float64
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 50413    False
# 50414    False
# 50415    False
# 50416    False
# 50417    False
# Length: 50418, dtype: bool

# %%
df3 = df.dropna()
df3
# Out:
# Empty DataFrame
# Columns: [index, iso_code, location, date, total_cases, total_deaths, stringency_index, population, gdp_per_capita, human_development_index, Unnamed: 10, Unnamed: 11, Unnamed: 12, Unnamed: 13, Unnamed: 14]
# Index: []

# %% [markdown]
# ## F. Drop particular column(s)

# %%
df.drop(['stringency_index'],axis=1) # we dropped stringency_index
# Out:
#        index iso_code     location        date  total_cases  total_deaths  \
# 0        NaN      AFG  Afghanistan  2019-12-31          0.0           0.0
# 1        NaN      AFG  Afghanistan  2020-01-01          0.0           0.0
# 2        NaN      AFG  Afghanistan  2020-01-02          0.0           0.0
# 3        NaN      AFG  Afghanistan  2020-01-03          0.0           0.0
# 4        NaN      AFG  Afghanistan  2020-01-04          0.0           0.0
# ...      ...      ...          ...         ...          ...           ...
# 50413    NaN      ZWE     Zimbabwe  2020-10-15       8055.0         231.0
# 50414    NaN      ZWE     Zimbabwe  2020-10-16       8075.0         231.0
# 50415    NaN      ZWE     Zimbabwe  2020-10-17       8099.0         231.0
# 50416    NaN      ZWE     Zimbabwe  2020-10-18       8110.0         231.0
# 50417    NaN      ZWE     Zimbabwe  2020-10-19       8147.0         231.0
#
#        population  gdp_per_capita  human_development_index  Unnamed: 10  \
# ...

# %% [markdown]
# ## G. Change column name(s)

# %%
df4 = df.rename(columns=({'human_development_index':'HDI'})) #pass inplace True if you want changes in orginal file

# %%
df4
# Out:
#        index iso_code     location        date  total_cases  total_deaths  \
# 0        NaN      AFG  Afghanistan  2019-12-31          0.0           0.0
# 1        NaN      AFG  Afghanistan  2020-01-01          0.0           0.0
# 2        NaN      AFG  Afghanistan  2020-01-02          0.0           0.0
# 3        NaN      AFG  Afghanistan  2020-01-03          0.0           0.0
# 4        NaN      AFG  Afghanistan  2020-01-04          0.0           0.0
# ...      ...      ...          ...         ...          ...           ...
# 50413    NaN      ZWE     Zimbabwe  2020-10-15       8055.0         231.0
# 50414    NaN      ZWE     Zimbabwe  2020-10-16       8075.0         231.0
# 50415    NaN      ZWE     Zimbabwe  2020-10-17       8099.0         231.0
# 50416    NaN      ZWE     Zimbabwe  2020-10-18       8110.0         231.0
# 50417    NaN      ZWE     Zimbabwe  2020-10-19       8147.0         231.0
#
#        stringency_index  population  gdp_per_capita    HDI  Unnamed: 10  \
# ...

# %% [markdown]
# ## H. Change column datatype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50418 entries, 0 to 50417
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    0 non-null      float64
#  1   iso_code                 50418 non-null  object
#  2   location                 50418 non-null  object
#  3   date                     50418 non-null  object
#  4   total_cases              47324 non-null  float64
#  5   total_deaths             39228 non-null  float64
#  6   stringency_index         43292 non-null  float64
#  7   population               50418 non-null  int64
#  8   gdp_per_capita           44706 non-null  float64
#  9   human_development_index  44216 non-null  float64
#  10  Unnamed: 10              50418 non-null  object
#  11  Unnamed: 11              50418 non-null  object
#  12  Unnamed: 12              50418 non-null  object
#  13  Unnamed: 13              50418 non-null  float64
# ...

# %%
df['population'] = df['population'].astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50418 entries, 0 to 50417
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    0 non-null      float64
#  1   iso_code                 50418 non-null  object
#  2   location                 50418 non-null  object
#  3   date                     50418 non-null  object
#  4   total_cases              47324 non-null  float64
#  5   total_deaths             39228 non-null  float64
#  6   stringency_index         43292 non-null  float64
#  7   population               50418 non-null  float64
#  8   gdp_per_capita           44706 non-null  float64
#  9   human_development_index  44216 non-null  float64
#  10  Unnamed: 10              50418 non-null  object
#  11  Unnamed: 11              50418 non-null  object
#  12  Unnamed: 12              50418 non-null  object
# ...

# %% [markdown]
# ## I. Change index

# %%
df4 = pd.DataFrame(df)

df4
# Out:
#        index iso_code     location        date  total_cases  total_deaths  \
# 0        NaN      AFG  Afghanistan  2019-12-31          0.0           0.0
# 1        NaN      AFG  Afghanistan  2020-01-01          0.0           0.0
# 2        NaN      AFG  Afghanistan  2020-01-02          0.0           0.0
# 3        NaN      AFG  Afghanistan  2020-01-03          0.0           0.0
# 4        NaN      AFG  Afghanistan  2020-01-04          0.0           0.0
# ...      ...      ...          ...         ...          ...           ...
# 50413    NaN      ZWE     Zimbabwe  2020-10-15       8055.0         231.0
# 50414    NaN      ZWE     Zimbabwe  2020-10-16       8075.0         231.0
# 50415    NaN      ZWE     Zimbabwe  2020-10-17       8099.0         231.0
# 50416    NaN      ZWE     Zimbabwe  2020-10-18       8110.0         231.0
# 50417    NaN      ZWE     Zimbabwe  2020-10-19       8147.0         231.0
#
#        stringency_index  population  gdp_per_capita  human_development_index  \
# ...

# %%
df = df.rename(index = lambda x: x + 1) 
  
df
# Out:
#        index iso_code     location        date  total_cases  total_deaths  \
# 1        NaN      AFG  Afghanistan  2019-12-31          0.0           0.0
# 2        NaN      AFG  Afghanistan  2020-01-01          0.0           0.0
# 3        NaN      AFG  Afghanistan  2020-01-02          0.0           0.0
# 4        NaN      AFG  Afghanistan  2020-01-03          0.0           0.0
# 5        NaN      AFG  Afghanistan  2020-01-04          0.0           0.0
# ...      ...      ...          ...         ...          ...           ...
# 50414    NaN      ZWE     Zimbabwe  2020-10-15       8055.0         231.0
# 50415    NaN      ZWE     Zimbabwe  2020-10-16       8075.0         231.0
# 50416    NaN      ZWE     Zimbabwe  2020-10-17       8099.0         231.0
# 50417    NaN      ZWE     Zimbabwe  2020-10-18       8110.0         231.0
# 50418    NaN      ZWE     Zimbabwe  2020-10-19       8147.0         231.0
#
#        stringency_index  population  gdp_per_capita  human_development_index  \
# ...

# %% [markdown]
# # K. Summarize unique values in text columns (values_count())

# %%
df.shape
# Out:
# (50418, 15)

# %%
dup = df.duplicated().sum()
print("Total unique value : ",df.shape[0] - dup)
# Out:
# Total unique value :  50418

# %% [markdown]
# # L. Show five number summary & related plot for numeric columns

# %%
df.describe()
# Out:
#        index   total_cases   total_deaths  stringency_index    population  \
# count    0.0  4.732400e+04   39228.000000      43292.000000  5.041800e+04
# mean     NaN  6.621927e+04    2978.767819         56.162022  4.251601e+07
# std      NaN  4.045582e+05   13836.644013         27.532685  1.564607e+08
# min      NaN  0.000000e+00       0.000000          0.000000  8.090000e+02
# 25%      NaN  1.260000e+02      10.000000         37.960000  1.399491e+06
# 50%      NaN  1.594000e+03      64.000000         61.110000  8.278737e+06
# 75%      NaN  1.584775e+04     564.000000         78.700000  2.913681e+07
# max      NaN  8.154595e+06  219674.000000        100.000000  1.439324e+09
#
#        gdp_per_capita  human_development_index   Unnamed: 13
# count    44706.000000             44216.000000  50418.000000
# mean     20818.706240                 0.720139     15.442097
# std      20441.365392                 0.160902      2.495039
# ...

# %% [markdown]
# # M. Plot histogram and scatter plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
filter_data = df.dropna(subset=['population'])

plt.figure(figsize=(14,8))

sns.distplot(filter_data['population'], kde=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df  = pd.read_csv("raw_data.csv")

df.plot(kind='scatter',x='total_cases',y='total_deaths') # scatter plot
